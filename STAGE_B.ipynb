# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/lamech.ngeno/energydata_complete.csv")

# %%
#1.Understanding the data

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
#clean Data
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
data.drop(['date'], inplace=True, axis=1)

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Appliances     0
# lights         0
# rv1            0
# Tdewpoint      0
# Visibility     0
# Windspeed      0
# RH_out         0
# Press_mm_hg    0
# T_out          0
# RH_9           0
# T9             0
# RH_8           0
# T8             0
# RH_7           0
# T7             0
# RH_6           0
# T6             0
# RH_5           0
# T5             0
# RH_4           0
# T4             0
# RH_3           0
# T3             0
# RH_2           0
# T2             0
# RH_1           0
# T1             0
# rv2            0
# dtype: int64

# %%
d=data['RH_5'].mean()+data['RH_6'].mean()+data['RH_2'].mean()+data['RH_4'].mean()+data['RH_1'].mean()+data['RH_3'].mean()+data['RH_7'].mean()+data['RH_8'].mean()+data['RH_9'].mean()

# %%
print (d)
# Out:
# 384.38469591689864

# %%
humiditymean = d/9
print (humiditymean)
# Out:
# 42.70941065743318

# %%
t=data['T1'].mean()+data['T2'].mean()+data['T3'].mean()+data['T4'].mean()+data['T5'].mean()+data['T6'].mean()+data['T7'].mean()+data['T8'].mean()+data['T9'].mean()

# %%
temperaturemean = t/9
print (temperaturemean)
# Out:
# 19.381758174670768

# %%
#Cast data to lean DataFrame
data['Average Temperature'] = temperaturemean
data['Average Humidity'] = humiditymean
data.head()
# Out:
#    Appliances  lights     T1       RH_1    T2       RH_2     T3       RH_3  \
# 0          60      30  19.89  47.596667  19.2  44.790000  19.79  44.730000
# 1          60      30  19.89  46.693333  19.2  44.722500  19.79  44.790000
# 2          50      30  19.89  46.300000  19.2  44.626667  19.79  44.933333
# 3          50      40  19.89  46.066667  19.2  44.590000  19.79  45.000000
# 4          60      40  19.89  46.333333  19.2  44.530000  19.79  45.000000
#
#           T4       RH_4  ...     T_out  Press_mm_hg  RH_out  Windspeed  \
# 0  19.000000  45.566667  ...  6.600000        733.5    92.0   7.000000
# 1  19.000000  45.992500  ...  6.483333        733.6    92.0   6.666667
# 2  18.926667  45.890000  ...  6.366667        733.7    92.0   6.333333
# 3  18.890000  45.723333  ...  6.250000        733.8    92.0   6.000000
# 4  18.890000  45.530000  ...  6.133333        733.9    92.0   5.666667
#
#    Visibility  Tdewpoint        rv1        rv2  Average Temperature  \
# ...

# %%
cast_df = data[['lights','Press_mm_hg','RH_out','Windspeed','Visibility','Tdewpoint','rv1','rv2','Average Temperature','Average Humidity']].copy()

# %%
cast_df.head()
# Out:
#    lights  Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# 0      30        733.5    92.0   7.000000   63.000000        5.3  13.275433
# 1      30        733.6    92.0   6.666667   59.166667        5.2  18.606195
# 2      30        733.7    92.0   6.333333   55.333333        5.1  28.642668
# 3      40        733.8    92.0   6.000000   51.500000        5.0  45.410389
# 4      40        733.9    92.0   5.666667   47.666667        4.9  10.084097
#
#          rv2  Average Temperature  Average Humidity
# 0  13.275433            19.381758         42.709411
# 1  18.606195            19.381758         42.709411
# 2  28.642668            19.381758         42.709411
# 3  45.410389            19.381758         42.709411
# 4  10.084097            19.381758         42.709411

# %%
data['Visibility'].describe
# Out:
# <bound method NDFrame.describe of 0        63.000000
# 1        59.166667
# 2        55.333333
# 3        51.500000
# 4        47.666667
#            ...
# 19730    23.666667
# 19731    24.500000
# 19732    25.333333
# 19733    26.166667
# 19734    27.000000
# Name: Visibility, Length: 19735, dtype: float64>

# %%
#analysing corelationship
corelation = data[['RH_1','RH_2','RH_3','Visibility']].corr()
sns.heatmap(corelation,annot = True, cmap = 'Reds')
plt.show()

# %%
#analysing corelationship
corelation = data[['T1','T2','T3','Visibility']].corr()
sns.heatmap(corelation,annot = True, cmap = 'Reds')
plt.show()

# %%
corelation = data.corr()
sns.heatmap(corelation,annot = True, cmap = 'Reds')
plt.show()

# %%
simple_linear_reg_df = data[['RH_1', 'Visibility']].sample(15, random_state=2)
simple_linear_temp_reg_df = data[['T1', 'Appliances']].sample(15, random_state=2)

# %%
#regression plot
sns.regplot(x="RH_1", y="Visibility",
data=simple_linear_reg_df)
# Out:
# <AxesSubplot:xlabel='RH_1', ylabel='Visibility'>

# %%
#regression plot
sns.regplot(x="T1", y="Appliances",
data=simple_linear_temp_reg_df)
# Out:
# <AxesSubplot:xlabel='T1', ylabel='Appliances'>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
features_df = normalised_df.drop(columns=['T2', 'T6'])
heating_target = normalised_df['T6']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, heating_target,
test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
# rss = np.sum(np.square(y_test - predicted_values))
# round(rss, 2) 
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 1.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
features_df = normalised_df.drop(columns=['lights'])
heating_target = normalised_df['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, heating_target,
test_size=0.3, random_state=1)

# %%
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 0.0

# %%
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 0.0

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.0
